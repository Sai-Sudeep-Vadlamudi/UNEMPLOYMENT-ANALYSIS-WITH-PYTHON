# %% [markdown]
# <a href="https://colab.research.google.com/github/Sai-Sudeep-Vadlamudi/UNEMPLOYMENT-ANALYSIS-WITH-PYTHON/blob/main/TASK2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import the libraries
import numpy as np
import pandas as pd
import sklearn
import plotly
import matplotlib
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
from google.colab import drive
#Import the dataset
drive.mount('/content/gdrive')
india1=pd.read_csv('/content/gdrive/MyDrive/oasis DS/Unemployment in India.csv')
india2=pd.read_csv('/content/gdrive/MyDrive/oasis DS/Unemployment_Rate_upto_11_2020.csv')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
india1.dropna(inplace=True)
india1
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
india2.dropna(inplace=True)
india2
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
india1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 46.2+ KB

# %%
india2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
india1.describe
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
india2.describe
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
#Checking null values
print(india1.isnull().sum())
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
#Checking null values
print(india2.isnull().sum())
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
plt.style.use("seaborn-whitegrid")
plt.figure(figsize=(12,10))
plt.title('Unemployment Rate in India')
sns.heatmap(india1.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
# <ipython-input-14-c05672521a04>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")
# <ipython-input-14-c05672521a04>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(india1.corr(), annot=True, cmap='coolwarm')

# %%
plt.style.use("seaborn-whitegrid")
plt.figure(figsize=(12,10))
plt.title('Unemployment Rate in India')
sns.heatmap(india2.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
# <ipython-input-15-a6548e283126>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")
# <ipython-input-15-a6548e283126>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(india2.corr(), annot=True, cmap='coolwarm')

# %%
india1.columns=['region','date','frequency','unemployed','employed','labour','area']
plt.figure(figsize=(20,15))
sns.histplot(x="employed",hue="region",data=india1)
plt.title("Employment Rate in India")
plt.show()

# %%
india2.columns=['region','date','frequency','unemployed','employed','labour','direction','longitude','latitude']
plt.figure(figsize=(15,15))
sns.histplot(x="employed",hue="region",data=india2)
plt.title("Employment Rate in India")
plt.show()

# %%
india1.columns=['region','date','frequency','unemployed','employed','labour','area']
plt.figure(figsize=(20,15))
sns.histplot(x="unemployed",hue="region",data=india1)
plt.title("Unemployment Rate in India")
plt.show()

# %%
india2.columns=['region','date','frequency','unemployed','employed','labour','direction','longitude','latitude']
plt.figure(figsize=(20,15))
sns.histplot(x="unemployed",hue="region",data=india1)
plt.title("Unemployment Rate in India")
plt.show()

# %%
sns.pairplot(india1,height=4.5)

# %%
sns.pairplot(india2,height=4.5)

# %%
sns.pairplot(india1,height=4.9, hue="region")

# %%
sns.pairplot(india2,height=5, hue="direction")

# %%
india1.columns=['region','date','frequency','unemployed','employed','labour','area']
unemployment=india1.iloc[:,[0,3,6]].copy()
unemployment
figure=px.sunburst(unemployment,path=['area','region'],values='unemployed',width=700,height=700,title='Unemployment rate in India')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
india2.columns=['region','date','frequency','unemployed','employed','labour','direction','longitude','latitude']
unemployment=india2.iloc[:,[0,3,6]].copy()
unemployment
figure=px.sunburst(unemployment,path=['direction','region'],values='unemployed',width=700,height=700,title='Unemployment rate in India')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
india1.columns=['region','date','frequency','unemployed','employed','labour','area']
india2.columns=['region','date','frequency','unemployed','employed','labour','direction','longitude','latitude']
fig=plt.figure(figsize=(20,10))
ax=sns.lineplot(y="unemployed",x="region",data=india1)
ax1=sns.lineplot(y="unemployed",x="region",data=india2)
plt.xticks(rotation=40)
plt.show()
